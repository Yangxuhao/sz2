# %%
import numpy as np
from sklearn.linear_model import LogisticRegression#导入逻辑回归包
from sklearn.datasets import make_blobs#创造散点数据
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
data,target=make_blobs(n_samples=150,n_features=2,
                       centers=[[0,0],[3,-1],[4,2]],
                       cluster_std=0.8)
data
# Out:
# array([[ 3.26531153,  2.57759617],
#        [ 3.21964491,  1.78085694],
#        [ 2.99186215, -0.27707574],
#        [ 4.00913073,  2.75771228],
#        [ 3.05409698,  0.69594317],
#        [ 2.76756988, -1.20111659],
#        [ 3.35582601,  1.35649423],
#        [-0.07785095,  0.7443787 ],
#        [-1.01256113, -0.11843328],
#        [-0.23644061, -1.16650955],
#        [ 2.76739444, -1.21348256],
#        [-0.81949605,  0.22541838],
#        [ 4.14887051,  2.35664281],
#        [ 4.87980347,  1.92466568],
#        [ 1.21451221, -0.53849312],
#        [-0.26793604, -0.27127955],
#        [-0.7124058 , -0.73112321],
#        [ 2.48137919, -1.74627327],
#        [ 3.32350433, -1.09998061],
#        [-0.04786543,  1.18420139],
#        [ 1.560536  ,  0.04543723],
#        [ 2.08405615, -0.95220765],
#        [ 1.55549041,  0.45927524],
#        [ 1.59725121, -0.03233591],
#        [ 2.60250977, -1.11874987],
#        [ 3.09267899, -0.20028917],
#        [ 2.86234578, -1.02114194],
# ...

# %%
target
# Out:
# array([2, 2, 1, 2, 2, 1, 2, 0, 0, 0, 1, 0, 2, 2, 1, 0, 0, 1, 1, 0, 0, 1,
#        0, 0, 1, 2, 1, 2, 2, 2, 0, 2, 2, 0, 2, 2, 2, 0, 1, 0, 0, 2, 1, 0,
#        0, 0, 0, 1, 0, 1, 2, 0, 1, 0, 2, 1, 2, 0, 2, 2, 1, 1, 2, 0, 0, 1,
#        1, 1, 1, 2, 1, 2, 0, 1, 2, 0, 2, 1, 0, 1, 2, 0, 2, 2, 2, 0, 0, 0,
#        2, 1, 2, 1, 2, 1, 1, 2, 1, 1, 1, 1, 0, 2, 2, 1, 0, 0, 0, 1, 1, 0,
#        2, 1, 0, 2, 1, 1, 0, 1, 0, 2, 0, 0, 2, 2, 2, 1, 1, 1, 2, 2, 0, 1,
#        1, 1, 1, 2, 0, 1, 1, 2, 1, 0, 0, 2, 0, 2, 2, 0, 0, 0])

# %%
plt.scatter(data[:,0],data[:,1],c=target)

# %%
lr=LogisticRegression(solver='liblinear',multi_class='auto')
lr.fit(data,target)
# Out:
# LogisticRegression(C=1.0, class_weight=None, dual=False, fit_intercept=True,
#           intercept_scaling=1, max_iter=100, multi_class='auto',
#           n_jobs=None, penalty='l2', random_state=None, solver='liblinear',
#           tol=0.0001, verbose=0, warm_start=False)

# %%
x_min,x_max=data[:,0].min()-1,data[:,0].max()+1
y_min,y_max=data[:,1].min()-1,data[:,1].max()+1

# %%
x,y=np.arange(x_min,x_max,0.01),np.arange(y_min,y_max,0.01)

# %%
xx,yy=np.meshgrid(x,y)

# %%
xx[:10]
# Out:
# array([[-2.81233517, -2.80233517, -2.79233517, ...,  6.56766483,
#          6.57766483,  6.58766483],
#        [-2.81233517, -2.80233517, -2.79233517, ...,  6.56766483,
#          6.57766483,  6.58766483],
#        [-2.81233517, -2.80233517, -2.79233517, ...,  6.56766483,
#          6.57766483,  6.58766483],
#        ...,
#        [-2.81233517, -2.80233517, -2.79233517, ...,  6.56766483,
#          6.57766483,  6.58766483],
#        [-2.81233517, -2.80233517, -2.79233517, ...,  6.56766483,
#          6.57766483,  6.58766483],
#        [-2.81233517, -2.80233517, -2.79233517, ...,  6.56766483,
#          6.57766483,  6.58766483]])

# %%
yy.shape
# Out:
# (775, 941)

# %%
xy_test=np.c_[xx.ravel(),yy.ravel()]

# %%
xy_test.shape
# Out:
# (729275, 2)

# %%
y_new=lr.predict(xy_test)
z=y_new.reshape(yy.shape)

# %%
plt.pcolormesh(xx,yy,z,cmap="rainbow")
plt.scatter(data[:,0],data[:,1],c=target,cmap="gray")
